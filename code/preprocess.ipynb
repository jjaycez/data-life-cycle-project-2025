# %% [markdown]
# # Setting environment

# %%
from pathlib import Path
import os
# get current file directory
cfd = Path.cwd()
print(f"Current file directory: {cfd}")
new_cwd = cfd.parent
os.chdir(new_cwd)
print(f"Current working directory changed to: {Path.cwd()}")
# Out:
# Current file directory: /mnt/c/Users/Usuario/PycharmProjects/data-life-cycle-project-2025/code
# Current working directory changed to: /mnt/c/Users/Usuario/PycharmProjects/data-life-cycle-project-2025

# %%
# !ls
# Out:
# LICENSE  README.md  code  data	input  tex

# %% [markdown]
# # Explore asthma dataset

# %% [markdown]
# ## Inspect metadata

# %%
# load metadata
import json
raw_data_dir = Path("data/raw")
with open(raw_data_dir / "metadata.json", "r") as f:
    metadata = json.load(f)
# pretty print data
import pprint
pprint.pprint(metadata)
# Out:
# {'@type': 'dcat:Dataset',
#  'accessLevel': 'public',
#  'contactPoint': {'@type': 'vcard:Contact',
#                   'fn': 'California Department of Public Health, California '
#                         'Breathing Asthma Program',
#                   'hasEmail': 'mailto:California.Breathing@cdph.ca.gov'},
#  'description': 'This dataset contains the estimated percentage of '
#                 'Californians with asthma (asthma prevalence). Two types of '
#                 'asthma prevalence are included: 1) lifetime asthma prevalence '
#                 'describes the percentage of people who have ever been '
#                 'diagnosed with asthma by a health care provider, 2) current '
#                 'asthma prevalence describes the percentage of people who have '
#                 'ever been diagnosed with asthma by a health care provider AND '
#                 'report they still have asthma and/or had an asthma episode or '
#                 'attack within the past 12 months. The tables “Lifetime Asthma '
#                 'Prevalence by County” and “Current Asthma Prevalence by '
#                 'County” are derived from the California Health Interview '
#                 'Survey (CHIS) and include data stratified by county and age '
#                 'group (all ages, 0-17, 18+, 0-4, 5-17, 18-64, 65+) reported '
#                 'for 2-year periods. The table “Asthma Prevalence, Adults (18 '
#                 'and older)” is derived from the California Behavioral Risk '
#                 'Factor Surveillance System (BRFSS) and includes statewide '
#                 'data on adults reported by year.',
#  'distribution': [{'@type': 'dcat:Distribution',
#                    'describedBy': 'https://data.ca.gov/api/action/datastore_search?resource_id=d8a47eeb-1907-4f09-8703-22d889347516&limit=0',
#                    'describedByType': 'application/json',
#                    'description': 'This dataset contains current asthma '
#                                   'prevalence, the estimated percentage of '
#                                   'Californians who have ever been diagnosed '
#                                   'with asthma by a health care provider AND '
#                                   'report they still have asthma and/or had an '
#                                   'asthma episode or attack within the past 12 '
#                                   'months, statewide and by county. The data '
#                                   'are stratified by age group (all ages, '
#                                   '0-17, 18+, 0-4, 5-17, 18-64, 65+) and '
#                                   'reported for 2-year periods. These data are '
#                                   'derived from the California Health '
#                                   'Interview Survey (CHIS).',
#                    'downloadURL': 'https://data.chhs.ca.gov/dataset/01f456c3-db34-44f2-a52c-6811bef8ba6d/resource/a440b99b-ccc6-473c-bea1-2baf36b05dbe/download/current-asthma-prevalence-by-county-2015_2022.csv',
#                    'format': 'CSV',
#                    'mediaType': 'text/csv',
#                    'title': 'CHIS Data-Current Asthma Prevalence by County '
#                             '2015-Present'},
#                   {'@type': 'dcat:Distribution',
#                    'description': 'Data Dictionary for '
#                                   'https://data.chhs.ca.gov/dataset/01f456c3-db34-44f2-a52c-6811bef8ba6d/resource/a440b99b-ccc6-473c-bea1-2baf36b05dbe/download/current-asthma-prevalence-by-county-2015_2022.csv',
#                    'downloadURL': 'https://data.ca.gov/datastore/dictionary_download/d8a47eeb-1907-4f09-8703-22d889347516',
#                    'format': 'CSV',
#                    'isDataDictionary': True,
#                    'mediaType': 'text/csv',
#                    'title': 'Data Dictionary - CHIS Data-Current Asthma '
#                             'Prevalence by County 2015-Present'},
#                   {'@type': 'dcat:Distribution',
#                    'describedBy': 'https://data.ca.gov/api/action/datastore_search?resource_id=afa76377-f871-4608-82d0-7caf9efca8bf&limit=0',
#                    'describedByType': 'application/json',
#                    'description': 'This dataset contains lifetime asthma '
#                                   'prevalence, the estimated percentage of '
#                                   'Californians who have ever been diagnosed '
#                                   'with asthma by a health care provider, '
#                                   'statewide and by county. The data are '
#                                   'stratified by age group (all ages, 0-17, '
#                                   '18+, 0-4, 5-17, 18-64, 65+) and reported '
#                                   'for 2-year periods. These data are derived '
#                                   'from the California Health Interview Survey '
#                                   '(CHIS).',
#                    'downloadURL': 'https://data.chhs.ca.gov/dataset/01f456c3-db34-44f2-a52c-6811bef8ba6d/resource/0b88f23c-7781-474f-8687-15bd1f206265/download/lifetime-asthma-prevalence-by-county-2015_2022.csv',
#                    'format': 'CSV',
#                    'mediaType': 'text/csv',
#                    'title': 'CHIS Data-Lifetime Asthma Prevalence by County '
#                             '2015-Present'},
#                   {'@type': 'dcat:Distribution',
#                    'description': 'Data Dictionary for '
#                                   'https://data.chhs.ca.gov/dataset/01f456c3-db34-44f2-a52c-6811bef8ba6d/resource/0b88f23c-7781-474f-8687-15bd1f206265/download/lifetime-asthma-prevalence-by-county-2015_2022.csv',
#                    'downloadURL': 'https://data.ca.gov/datastore/dictionary_download/afa76377-f871-4608-82d0-7caf9efca8bf',
#                    'format': 'CSV',
#                    'isDataDictionary': True,
#                    'mediaType': 'text/csv',
#                    'title': 'Data Dictionary - CHIS Data-Lifetime Asthma '
#                             'Prevalence by County 2015-Present'},
#                   {'@type': 'dcat:Distribution',
#                    'describedBy': 'https://data.ca.gov/api/action/datastore_search?resource_id=e9466527-f20f-4490-89e4-ded9b18bced7&limit=0',
#                    'describedByType': 'application/json',
#                    'description': 'This dataset contains the estimated percent '
#                                   'of California adults (18 and older) with '
#                                   'lifetime and current asthma (asthma '
#                                   'prevalence), by year for 2012 to currently '
#                                   'available data. In 2012, the survey '
#                                   'methodology of the BRFS changed '
#                                   'significantly so that the survey would be '
#                                   'more representative of the general '
#                                   'population. Several changes were '
#                                   'implemented: 1) the survey included both '
#                                   'cell and landline random-digit dial '
#                                   'components, 2) residents of college housing '
#                                   'were eligible to complete the survey, and '
#                                   '3) new methods were used to calculate the '
#                                   'survey weights. Due to these changes, '
#                                   'estimates from 1984 – 2011 are not '
#                                   'comparable to estimates from 2012 and '
#                                   'beyond. CDPH and CDC recommend not '
#                                   'conducting analyses where estimates from '
#                                   '1984 – 2011 are compared with analyses '
#                                   'using the new methodology, beginning in '
#                                   '2012. This includes analyses examining '
#                                   'trends and changes over time. Please refer '
#                                   'to the attachment for '
#                                   'AsthmaPrevalence-Adults-by-Year-CA-Description.pdf.',
#                    'downloadURL': 'https://data.chhs.ca.gov/dataset/01f456c3-db34-44f2-a52c-6811bef8ba6d/resource/4dc6e239-97b0-475b-94b6-bec1a7f87729/download/brfssasthmaprevalence-adults-by-year-2012to2022-ca-cdphjul.csv',
#                    'format': 'CSV',
#                    'mediaType': 'text/csv',
#                    'title': 'BRFSS Data-Adult Asthma Prevalence 2012 to '
#                             'Present'},
#                   {'@type': 'dcat:Distribution',
#                    'description': 'Data Dictionary for '
#                                   'https://data.chhs.ca.gov/dataset/01f456c3-db34-44f2-a52c-6811bef8ba6d/resource/4dc6e239-97b0-475b-94b6-bec1a7f87729/download/brfssasthmaprevalence-adults-by-year-2012to2022-ca-cdphjul.csv',
#                    'downloadURL': 'https://data.ca.gov/datastore/dictionary_download/e9466527-f20f-4490-89e4-ded9b18bced7',
#                    'format': 'CSV',
#                    'isDataDictionary': True,
#                    'mediaType': 'text/csv',
#                    'title': 'Data Dictionary - BRFSS Data-Adult Asthma '
#                             'Prevalence 2012 to Present'},
#                   {'@type': 'dcat:Distribution',
#                    'describedBy': 'https://data.ca.gov/api/action/datastore_search?resource_id=5b8cf951-8aff-4861-bdd6-f8c30476caeb&limit=0',
#                    'describedByType': 'application/json',
#                    'description': 'This table contains the estimated percent '
#                                   'of California adults (18 and older) with '
#                                   'lifetime and current asthma (asthma '
#                                   'prevalence), by year. The data are derived '
#                                   'from the California Behavioral Risk Factor '
#                                   'Surveillance System (BRFSS). These data are '
#                                   'based on self-report from telephone surveys '
#                                   'and are subject to bias and low response '
#                                   'rates. In 2012, the survey methodology of '
#                                   'the BRFS changed significantly so that the '
#                                   'survey would be more representative of the '
#                                   'general population. Several changes were '
#                                   'implemented: 1) the survey included both '
#                                   'cell and landline random-digit dial '
#                                   'components, 2) residents of college housing '
#                                   'were eligible to complete the survey, and '
#                                   '3) new methods were used to calculate the '
#                                   'survey weights. Due to these changes, '
#                                   'estimates from 1984 – 2011 are not '
#                                   'comparable to estimates from 2012 and '
#                                   'beyond. CDPH and CDC recommend not '
#                                   'conducting analyses where estimates from '
#                                   '1984 – 2011 are compared with analyses '
#                                   'using the new methodology, beginning in '
#                                   '2012. This includes analyses examining '
#                                   'trends and changes over time. Please refer '
#                                   'to the attachment for '
#                                   'AsthmaPrevalence-Adults-by-Year-CA-Description.pdf.',
#                    'downloadURL': 'https://data.chhs.ca.gov/dataset/01f456c3-db34-44f2-a52c-6811bef8ba6d/resource/d782d003-8041-4a8e-ad83-ff996ed4443f/download/asthma-prevalence-adults-18-and-older-by-year-1995-to-2011.csv',
#                    'format': 'CSV',
#                    'mediaType': 'text/csv',
#                    'title': 'BRFSS Data-Adult Asthma Prevalence 1995 to 2011'},
#                   {'@type': 'dcat:Distribution',
#                    'description': 'Data Dictionary for '
#                                   'https://data.chhs.ca.gov/dataset/01f456c3-db34-44f2-a52c-6811bef8ba6d/resource/d782d003-8041-4a8e-ad83-ff996ed4443f/download/asthma-prevalence-adults-18-and-older-by-year-1995-to-2011.csv',
#                    'downloadURL': 'https://data.ca.gov/datastore/dictionary_download/5b8cf951-8aff-4861-bdd6-f8c30476caeb',
#                    'format': 'CSV',
#                    'isDataDictionary': True,
#                    'mediaType': 'text/csv',
#                    'title': 'Data Dictionary - BRFSS Data-Adult Asthma '
#                             'Prevalence 1995 to 2011'},
#                   {'@type': 'dcat:Distribution',
#                    'description': 'This dataset contains the estimated percent '
#                                   'of California adults (18 and older) with '
#                                   'lifetime and current asthma (asthma '
#                                   'prevalence), by year. The data are derived '
#                                   'from the California Behavioral Risk Factor '
#                                   'Surveillance System (BRFSS). These data are '
#                                   'based on self-report from telephone surveys '
#                                   'and are subject to bias and low response '
#                                   'rates. In 2012, the survey methodology of '
#                                   'the BRFS changed significantly so that the '
#                                   'survey would be more representative of the '
#                                   'general population. Several changes were '
#                                   'implemented: 1) the survey included both '
#                                   'cell and landline random-digit dial '
#                                   'components, 2) residents of college housing '
#                                   'were eligible to complete the survey, and '
#                                   '3) new methods were used to calculate the '
#                                   'survey weights. Due to these changes, '
#                                   'estimates from 1984 – 2011 are not '
#                                   'comparable to estimates from 2012 and '
#                                   'beyond. CDPH and CDC recommend not '
#                                   'conducting analyses where estimates from '
#                                   '1984 – 2011 are compared with analyses '
#                                   'using the new methodology, beginning in '
#                                   '2012. This includes analyses examining '
#                                   'trends and changes over time. Please refer '
#                                   'to the attachment for '
#                                   'AsthmaPrevalence-Adults-by-Year-CA-Description.pdf.',
#                    'downloadURL': 'https://data.chhs.ca.gov/dataset/01f456c3-db34-44f2-a52c-6811bef8ba6d/resource/17565f2a-eb2b-4abd-b19e-2b6ec471e7b0/download/asthmaprevalence-adults-by-year-ca-description.pdf',
#                    'format': 'PDF',
#                    'mediaType': 'application/pdf',
#                    'title': 'BRFSS Data-Asthma Prevalence Description'},
#                   {'@type': 'dcat:Distribution',
#                    'downloadURL': 'https://data.chhs.ca.gov/dataset/01f456c3-db34-44f2-a52c-6811bef8ba6d/resource/b413c764-2cfe-4aec-983b-bcce626dc3a8/download/asthma-prevalence-4n6vybjm.zip',
#                    'format': 'ZIP',
#                    'mediaType': 'application/zip',
#                    'title': 'All resource data'}],
#  'identifier': 'd1e6cc68-12d1-4b8a-8e16-709e80cadd11',
#  'issued': '2017-06-16T22:19:44.810684',
#  'keyword': ['BRFSS',
#              'CHIS',
#              'California Behavorial Risk Factor Surveillance System',
#              'California Breathing',
#              'California Health Interview Survey',
#              'Prevalence',
#              'asthma',
#              'california department of public health',
#              'chronic disease',
#              'disease of respiratory system',
#              'health effects',
#              'health outcome',
#              'respiratory disease'],
#  'license': 'http://www.opendefinition.org/licenses/cc-by',
#  'modified': '2025-11-06T23:04:32.157248',
#  'publisher': {'@type': 'org:Organization',
#                'name': 'California Department of Public Health'},
#  'theme': ['Health and Human Services'],
#  'title': 'Asthma Prevalence'}

# %% [markdown]
# ## Download and extract geographical data

# %%
import requests
# download county shapefiles from US Census Bureau
shapes_url = 'https://www2.census.gov/geo/tiger/TIGER2025/COUNTY/tl_2025_us_county.zip'
geo_dir = Path("data/geographical")
geo_dir.mkdir(parents=True, exist_ok=True)
shapes_path = geo_dir / "tl_2025_us_county.zip"
if not shapes_path.exists():
    print(f"Downloading county shapefiles from {shapes_url}...")
    r = requests.get(shapes_url)
    with open(shapes_path, 'wb') as f:
        f.write(r.content)
    print(f"Downloaded to {shapes_path}")
else:
    print(f"Shapefiles already exist at {shapes_path}")
# Out:
# Downloading county shapefiles from https://www2.census.gov/geo/tiger/TIGER2025/COUNTY/tl_2025_us_county.zip...
# Downloaded to data/geographical/tl_2025_us_county.zip

# %%
# extract shapefiles to subdirectory
import zipfile
with zipfile.ZipFile(shapes_path, 'r') as zip_ref:
    zip_ref.extractall(geo_dir / "california counties")
print(f"Extracted shapefiles to {geo_dir / 'california counties'}")
# Out:
# Extracted shapefiles to data/geographical/california counties

# %% [markdown]
# ## Inspect geographical data

# %%
# load shapefiles using geopandas
import geopandas as gpd
shapefile_path = geo_dir / "california counties" / "tl_2025_us_county.shp"
counties_gdf = gpd.read_file(shapefile_path)
counties_gdf.head()
# Out:
#   STATEFP COUNTYFP  COUNTYNS  GEOID         GEOIDFQ      NAME  \
# 0      40      075  01101825  40075  0500000US40075     Kiowa
# 1      46      079  01265776  46079  0500000US46079      Lake
# 2      37      033  01008542  37033  0500000US37033   Caswell
# 3      48      377  01383974  48377  0500000US48377  Presidio
# 4      39      057  01074041  39057  0500000US39057    Greene
#
#           NAMELSAD LSAD CLASSFP  MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT  \
# 0     Kiowa County   06      H1  G4020  None   None     None        A
# 1      Lake County   06      H1  G4020  None   None     None        A
# 2   Caswell County   06      H1  G4020  None   None     None        A
# 3  Presidio County   06      H1  G4020  None   None     None        A
# 4    Greene County   06      H1  G4020   212  19430     None        A
#
#         ALAND    AWATER     INTPTLAT      INTPTLON  \
# 0  2629039892  40296743  +34.9214893  -098.9816168
# 1  1457916151  31746795  +44.0284497  -097.1232229
# 2  1102042927   8293623  +36.3943252  -079.3396193
# 3  9985057447   1773188  +30.0058912  -104.2616192
# 4  1071302625   6798109  +39.6874785  -083.8948943
#
#                                             geometry
# 0  POLYGON ((-98.95506 35.11643, -98.94903 35.116...
# 1  POLYGON ((-96.88886 43.9353, -96.88886 43.9351...
# 2  POLYGON ((-79.14343 36.4422, -79.14345 36.4418...
# 3  POLYGON ((-104.98078 30.62552, -104.98073 30.6...
# 4  POLYGON ((-84.10668 39.68891, -84.10662 39.689...

# %%
# california state uses STATEFP = 06
california_counties = counties_gdf[counties_gdf['STATEFP'] == '06']
california_counties
# Out:
#      STATEFP COUNTYFP  COUNTYNS  GEOID         GEOIDFQ             NAME  \
# 31        06      077  00277303  06077  0500000US06077      San Joaquin
# 74        06      025  00277277  06025  0500000US06025         Imperial
# 272       06      089  01682610  06089  0500000US06089           Shasta
# 357       06      023  01681908  06023  0500000US06023         Humboldt
# 362       06      059  00277294  06059  0500000US06059           Orange
# 383       06      047  00277288  06047  0500000US06047           Merced
# 442       06      105  00277317  06105  0500000US06105          Trinity
# 452       06      053  00277291  06053  0500000US06053         Monterey
# 462       06      005  01675841  06005  0500000US06005           Amador
# 817       06      071  00277300  06071  0500000US06071   San Bernardino
# 963       06      111  00277320  06111  0500000US06111          Ventura
# 1116      06      113  00277321  06113  0500000US06113             Yolo
# 1168      06      041  00277285  06041  0500000US06041            Marin
# 1282      06      001  01675839  06001  0500000US06001          Alameda
# 1344      06      027  01804637  06027  0500000US06027             Inyo
# 1440      06      093  00277311  06093  0500000US06093         Siskiyou
# 1446      06      045  00277287  06045  0500000US06045        Mendocino
# 1458      06      043  00277286  06043  0500000US06043         Mariposa
# 1542      06      017  00277273  06017  0500000US06017        El Dorado
# 1568      06      003  01675840  06003  0500000US06003           Alpine
# 1609      06      021  00277275  06021  0500000US06021            Glenn
# 1695      06      033  00277281  06033  0500000US06033             Lake
# 1714      06      081  00277305  06081  0500000US06081        San Mateo
# 1730      06      029  02054176  06029  0500000US06029             Kern
# 1764      06      069  00277299  06069  0500000US06069       San Benito
# 1779      06      079  00277304  06079  0500000US06079  San Luis Obispo
# 1878      06      039  00277284  06039  0500000US06039           Madera
# 1895      06      031  00277280  06031  0500000US06031            Kings
# 1896      06      073  00277301  06073  0500000US06073        San Diego
# 1909      06      061  00277295  06061  0500000US06061           Placer
# 1936      06      011  01675902  06011  0500000US06011           Colusa
# 1993      06      037  00277283  06037  0500000US06037      Los Angeles
# 2038      06      013  01675903  06013  0500000US06013     Contra Costa
# 2046      06      115  00277322  06115  0500000US06115             Yuba
# 2071      06      015  01682074  06015  0500000US06015        Del Norte
# 1695  POLYGON ((-122.41588 38.7682, -122.41626 38.76...
# 1714  POLYGON ((-122.58679 37.58998, -122.58645 37.5...
# 1730  POLYGON ((-118.88168 34.81785, -118.88204 34.8...
# 1764  POLYGON ((-121.644 36.894, -121.644 36.89401, ...
# 1779  POLYGON ((-120.71904 35.10983, -120.7223 35.11...
# 1878  POLYGON ((-120.16869 36.80346, -120.16953 36.8...
# 1895  POLYGON ((-119.53627 36.06527, -119.53627 36.0...
# 1896  POLYGON ((-116.7573 32.56551, -116.78255 32.56...
# 1909  POLYGON ((-120.00645 39.28083, -120.00645 39.2...
# 1936  POLYGON ((-121.91512 38.92535, -121.91527 38.9...
# 1993  MULTIPOLYGON (((-118.02878 33.87332, -118.0287...
# 2038  POLYGON ((-121.69732 37.78244, -121.69748 37.7...
# 2046  POLYGON ((-121.48786 38.99064, -121.48791 38.9...
# 2071  POLYGON ((-124.31611 41.72839, -124.33061 41.7...
# 2178  POLYGON ((-120.55587 39.50874, -120.55614 39.5...
# 2205  POLYGON ((-121.61025 39.05691, -121.61026 39.0...
# 2259  POLYGON ((-120.88251 41.18401, -120.88146 41.1...
# 2272  POLYGON ((-122.06943 39.84053, -122.06874 39.8...
# 2332  POLYGON ((-121.43991 38.25553, -121.44002 38.2...
# 2336  MULTIPOLYGON (((-119.11717 33.5056, -119.11508...
# 2381  POLYGON ((-120.71714 39.48896, -120.71709 39.4...
# 2400  MULTIPOLYGON (((-122.40537 37.70829, -122.4055...
# 2435  POLYGON ((-120.20886 41.1841, -120.21004 41.18...
# 2494  POLYGON ((-122.63507 38.58301, -122.63506 38.5...
# 2524  POLYGON ((-119.65138 38.28664, -119.65018 38.2...
# 2525  POLYGON ((-120.50016 38.00412, -120.50026 38.0...
# 2530  POLYGON ((-121.8616 38.06989, -121.86229 38.06...
# 2615  POLYGON ((-122.10363 38.51216, -122.10364 38.5...
# 2637  POLYGON ((-119.57319 36.48884, -119.57322 36.4...
# 2702  POLYGON ((-120.59907 37.55105, -120.60245 37.5...
# 2785  POLYGON ((-120.77048 39.71776, -120.77082 39.7...
# 2921  POLYGON ((-120.6318 38.34603, -120.63066 38.34...
# 2943  POLYGON ((-114.7665 33.43374, -114.76696 33.43...
# 2988  POLYGON ((-122.05188 36.8196, -122.05722 36.83...
# 3046  POLYGON ((-119.17479 36.65888, -119.1747 36.65...
# 3119  POLYGON ((-122.2026 37.36322, -122.20227 37.36...
# 3127  POLYGON ((-122.19917 40.37794, -122.19913 40.3...

# %% [markdown]
# ## Filter OpenAQ stations to California

# %%
import yaml

with open(Path.cwd() / "code" / "keys.yaml", 'r') as f:
   keys = yaml.safe_load(f)
openaq_key = keys['api_keys']['OpenAQ']
openaq_key
# Out:
# '94e6fcef08ee681b1921a232bc2dcbbaf3959e917a7e4c3e50582c59c9557199'

# %%
x_range = (-125, -113)
y_range = (32, 42.5)
import requests
openaq_url = "https://api.openaq.org/v2/locations"
params = {
    "country": "US",
    "coordinates": f"{(y_range[0] + y_range[1]) / 2},{(x_range[0] + x_range[1]) / 2}",
    "radius": 500000,  # in meters
    "limit": 10000,
