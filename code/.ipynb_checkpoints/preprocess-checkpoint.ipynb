# %% [markdown]
# # Setting environment

# %%
from pathlib import Path
import os
# get current file directory
cfd = Path.cwd()
print(f"Current file directory: {cfd}")
new_cwd = cfd.parent
os.chdir(new_cwd)
print(f"Current working directory changed to: {Path.cwd()}")
# Out:
# Current file directory: /mnt/c/Users/Usuario/PycharmProjects/data-life-cycle-project-2025/code
# Current working directory changed to: /mnt/c/Users/Usuario/PycharmProjects/data-life-cycle-project-2025

# %%
# !ls
# Out:
# LICENSE  README.md  code  data	input  tex

# %% [markdown]
# # Explore asthma dataset

# %% [markdown]
# ## Inspect metadata

# %%
# load metadata
import json
raw_data_dir = Path("data/raw")
with open(raw_data_dir / "metadata.json", "r") as f:
    metadata = json.load(f)
# pretty print data
import pprint
pprint.pprint(metadata)
# Out:
# {'@type': 'dcat:Dataset',
#  'accessLevel': 'public',
#  'contactPoint': {'@type': 'vcard:Contact',
#                   'fn': 'California Department of Public Health, California '
#                         'Breathing Asthma Program',
#                   'hasEmail': 'mailto:California.Breathing@cdph.ca.gov'},
#  'description': 'This dataset contains the estimated percentage of '
#                 'Californians with asthma (asthma prevalence). Two types of '
#                 'asthma prevalence are included: 1) lifetime asthma prevalence '
#                 'describes the percentage of people who have ever been '
#                 'diagnosed with asthma by a health care provider, 2) current '
#                 'asthma prevalence describes the percentage of people who have '
#                 'ever been diagnosed with asthma by a health care provider AND '
#                 'report they still have asthma and/or had an asthma episode or '
#                 'attack within the past 12 months. The tables “Lifetime Asthma '
#                 'Prevalence by County” and “Current Asthma Prevalence by '
#                 'County” are derived from the California Health Interview '
#                 'Survey (CHIS) and include data stratified by county and age '
#                 'group (all ages, 0-17, 18+, 0-4, 5-17, 18-64, 65+) reported '
#                 'for 2-year periods. The table “Asthma Prevalence, Adults (18 '
#                 'and older)” is derived from the California Behavioral Risk '
#                 'Factor Surveillance System (BRFSS) and includes statewide '
#                 'data on adults reported by year.',
#  'distribution': [{'@type': 'dcat:Distribution',
#                    'describedBy': 'https://data.ca.gov/api/action/datastore_search?resource_id=d8a47eeb-1907-4f09-8703-22d889347516&limit=0',
#                    'describedByType': 'application/json',
#                    'description': 'This dataset contains current asthma '
#                                   'prevalence, the estimated percentage of '
#                                   'Californians who have ever been diagnosed '
#                                   'with asthma by a health care provider AND '
#                                   'report they still have asthma and/or had an '
#                                   'asthma episode or attack within the past 12 '
#                                   'months, statewide and by county. The data '
#                                   'are stratified by age group (all ages, '
#                                   '0-17, 18+, 0-4, 5-17, 18-64, 65+) and '
#                                   'reported for 2-year periods. These data are '
#                                   'derived from the California Health '
#                                   'Interview Survey (CHIS).',
#                    'downloadURL': 'https://data.chhs.ca.gov/dataset/01f456c3-db34-44f2-a52c-6811bef8ba6d/resource/a440b99b-ccc6-473c-bea1-2baf36b05dbe/download/current-asthma-prevalence-by-county-2015_2022.csv',
#                    'format': 'CSV',
#                    'mediaType': 'text/csv',
#                    'title': 'CHIS Data-Current Asthma Prevalence by County '
#                             '2015-Present'},
#                   {'@type': 'dcat:Distribution',
#                    'description': 'Data Dictionary for '
#                                   'https://data.chhs.ca.gov/dataset/01f456c3-db34-44f2-a52c-6811bef8ba6d/resource/a440b99b-ccc6-473c-bea1-2baf36b05dbe/download/current-asthma-prevalence-by-county-2015_2022.csv',
#                    'downloadURL': 'https://data.ca.gov/datastore/dictionary_download/d8a47eeb-1907-4f09-8703-22d889347516',
#                    'format': 'CSV',
#                    'isDataDictionary': True,
#                    'mediaType': 'text/csv',
#                    'title': 'Data Dictionary - CHIS Data-Current Asthma '
#                             'Prevalence by County 2015-Present'},
#                   {'@type': 'dcat:Distribution',
#                    'describedBy': 'https://data.ca.gov/api/action/datastore_search?resource_id=afa76377-f871-4608-82d0-7caf9efca8bf&limit=0',
#                    'describedByType': 'application/json',
#                    'description': 'This dataset contains lifetime asthma '
#                                   'prevalence, the estimated percentage of '
#                                   'Californians who have ever been diagnosed '
#                                   'with asthma by a health care provider, '
#                                   'statewide and by county. The data are '
#                                   'stratified by age group (all ages, 0-17, '
#                                   '18+, 0-4, 5-17, 18-64, 65+) and reported '
#                                   'for 2-year periods. These data are derived '
#                                   'from the California Health Interview Survey '
#                                   '(CHIS).',
#                    'downloadURL': 'https://data.chhs.ca.gov/dataset/01f456c3-db34-44f2-a52c-6811bef8ba6d/resource/0b88f23c-7781-474f-8687-15bd1f206265/download/lifetime-asthma-prevalence-by-county-2015_2022.csv',
#                    'format': 'CSV',
#                    'mediaType': 'text/csv',
#                    'title': 'CHIS Data-Lifetime Asthma Prevalence by County '
#                             '2015-Present'},
#                   {'@type': 'dcat:Distribution',
#                    'description': 'Data Dictionary for '
#                                   'https://data.chhs.ca.gov/dataset/01f456c3-db34-44f2-a52c-6811bef8ba6d/resource/0b88f23c-7781-474f-8687-15bd1f206265/download/lifetime-asthma-prevalence-by-county-2015_2022.csv',
#                    'downloadURL': 'https://data.ca.gov/datastore/dictionary_download/afa76377-f871-4608-82d0-7caf9efca8bf',
#                    'format': 'CSV',
#                    'isDataDictionary': True,
#                    'mediaType': 'text/csv',
#                    'title': 'Data Dictionary - CHIS Data-Lifetime Asthma '
#                             'Prevalence by County 2015-Present'},
#                   {'@type': 'dcat:Distribution',
#                    'describedBy': 'https://data.ca.gov/api/action/datastore_search?resource_id=e9466527-f20f-4490-89e4-ded9b18bced7&limit=0',
#                    'describedByType': 'application/json',
#                    'description': 'This dataset contains the estimated percent '
#                                   'of California adults (18 and older) with '
#                                   'lifetime and current asthma (asthma '
#                                   'prevalence), by year for 2012 to currently '
#                                   'available data. In 2012, the survey '
#                                   'methodology of the BRFS changed '
#                                   'significantly so that the survey would be '
#                                   'more representative of the general '
#                                   'population. Several changes were '
#                                   'implemented: 1) the survey included both '
#                                   'cell and landline random-digit dial '
#                                   'components, 2) residents of college housing '
#                                   'were eligible to complete the survey, and '
#                                   '3) new methods were used to calculate the '
#                                   'survey weights. Due to these changes, '
#                                   'estimates from 1984 – 2011 are not '
#                                   'comparable to estimates from 2012 and '
#                                   'beyond. CDPH and CDC recommend not '
#                                   'conducting analyses where estimates from '
#                                   '1984 – 2011 are compared with analyses '
#                                   'using the new methodology, beginning in '
#                                   '2012. This includes analyses examining '
#                                   'trends and changes over time. Please refer '
#                                   'to the attachment for '
#                                   'AsthmaPrevalence-Adults-by-Year-CA-Description.pdf.',
#                    'downloadURL': 'https://data.chhs.ca.gov/dataset/01f456c3-db34-44f2-a52c-6811bef8ba6d/resource/4dc6e239-97b0-475b-94b6-bec1a7f87729/download/brfssasthmaprevalence-adults-by-year-2012to2022-ca-cdphjul.csv',
#                    'format': 'CSV',
#                    'mediaType': 'text/csv',
#                    'title': 'BRFSS Data-Adult Asthma Prevalence 2012 to '
#                             'Present'},
#                   {'@type': 'dcat:Distribution',
#                    'description': 'Data Dictionary for '
#                                   'https://data.chhs.ca.gov/dataset/01f456c3-db34-44f2-a52c-6811bef8ba6d/resource/4dc6e239-97b0-475b-94b6-bec1a7f87729/download/brfssasthmaprevalence-adults-by-year-2012to2022-ca-cdphjul.csv',
#                    'downloadURL': 'https://data.ca.gov/datastore/dictionary_download/e9466527-f20f-4490-89e4-ded9b18bced7',
#                    'format': 'CSV',
#                    'isDataDictionary': True,
#                    'mediaType': 'text/csv',
#                    'title': 'Data Dictionary - BRFSS Data-Adult Asthma '
#                             'Prevalence 2012 to Present'},
#                   {'@type': 'dcat:Distribution',
#                    'describedBy': 'https://data.ca.gov/api/action/datastore_search?resource_id=5b8cf951-8aff-4861-bdd6-f8c30476caeb&limit=0',
#                    'describedByType': 'application/json',
#                    'description': 'This table contains the estimated percent '
#                                   'of California adults (18 and older) with '
#                                   'lifetime and current asthma (asthma '
#                                   'prevalence), by year. The data are derived '
#                                   'from the California Behavioral Risk Factor '
#                                   'Surveillance System (BRFSS). These data are '
#                                   'based on self-report from telephone surveys '
#                                   'and are subject to bias and low response '
#                                   'rates. In 2012, the survey methodology of '
#                                   'the BRFS changed significantly so that the '
#                                   'survey would be more representative of the '
#                                   'general population. Several changes were '
#                                   'implemented: 1) the survey included both '
#                                   'cell and landline random-digit dial '
#                                   'components, 2) residents of college housing '
#                                   'were eligible to complete the survey, and '
#                                   '3) new methods were used to calculate the '
#                                   'survey weights. Due to these changes, '
#                                   'estimates from 1984 – 2011 are not '
#                                   'comparable to estimates from 2012 and '
#                                   'beyond. CDPH and CDC recommend not '
#                                   'conducting analyses where estimates from '
#                                   '1984 – 2011 are compared with analyses '
#                                   'using the new methodology, beginning in '
#                                   '2012. This includes analyses examining '
#                                   'trends and changes over time. Please refer '
#                                   'to the attachment for '
#                                   'AsthmaPrevalence-Adults-by-Year-CA-Description.pdf.',
#                    'downloadURL': 'https://data.chhs.ca.gov/dataset/01f456c3-db34-44f2-a52c-6811bef8ba6d/resource/d782d003-8041-4a8e-ad83-ff996ed4443f/download/asthma-prevalence-adults-18-and-older-by-year-1995-to-2011.csv',
#                    'format': 'CSV',
#                    'mediaType': 'text/csv',
#                    'title': 'BRFSS Data-Adult Asthma Prevalence 1995 to 2011'},
#                   {'@type': 'dcat:Distribution',
#                    'description': 'Data Dictionary for '
#                                   'https://data.chhs.ca.gov/dataset/01f456c3-db34-44f2-a52c-6811bef8ba6d/resource/d782d003-8041-4a8e-ad83-ff996ed4443f/download/asthma-prevalence-adults-18-and-older-by-year-1995-to-2011.csv',
#                    'downloadURL': 'https://data.ca.gov/datastore/dictionary_download/5b8cf951-8aff-4861-bdd6-f8c30476caeb',
#                    'format': 'CSV',
#                    'isDataDictionary': True,
#                    'mediaType': 'text/csv',
#                    'title': 'Data Dictionary - BRFSS Data-Adult Asthma '
#                             'Prevalence 1995 to 2011'},
#                   {'@type': 'dcat:Distribution',
#                    'description': 'This dataset contains the estimated percent '
#                                   'of California adults (18 and older) with '
#                                   'lifetime and current asthma (asthma '
#                                   'prevalence), by year. The data are derived '
#                                   'from the California Behavioral Risk Factor '
#                                   'Surveillance System (BRFSS). These data are '
#                                   'based on self-report from telephone surveys '
#                                   'and are subject to bias and low response '
#                                   'rates. In 2012, the survey methodology of '
#                                   'the BRFS changed significantly so that the '
#                                   'survey would be more representative of the '
#                                   'general population. Several changes were '
#                                   'implemented: 1) the survey included both '
#                                   'cell and landline random-digit dial '
#                                   'components, 2) residents of college housing '
#                                   'were eligible to complete the survey, and '
#                                   '3) new methods were used to calculate the '
#                                   'survey weights. Due to these changes, '
#                                   'estimates from 1984 – 2011 are not '
#                                   'comparable to estimates from 2012 and '
#                                   'beyond. CDPH and CDC recommend not '
#                                   'conducting analyses where estimates from '
#                                   '1984 – 2011 are compared with analyses '
#                                   'using the new methodology, beginning in '
#                                   '2012. This includes analyses examining '
#                                   'trends and changes over time. Please refer '
#                                   'to the attachment for '
#                                   'AsthmaPrevalence-Adults-by-Year-CA-Description.pdf.',
#                    'downloadURL': 'https://data.chhs.ca.gov/dataset/01f456c3-db34-44f2-a52c-6811bef8ba6d/resource/17565f2a-eb2b-4abd-b19e-2b6ec471e7b0/download/asthmaprevalence-adults-by-year-ca-description.pdf',
#                    'format': 'PDF',
#                    'mediaType': 'application/pdf',
#                    'title': 'BRFSS Data-Asthma Prevalence Description'},
#                   {'@type': 'dcat:Distribution',
#                    'downloadURL': 'https://data.chhs.ca.gov/dataset/01f456c3-db34-44f2-a52c-6811bef8ba6d/resource/b413c764-2cfe-4aec-983b-bcce626dc3a8/download/asthma-prevalence-4n6vybjm.zip',
#                    'format': 'ZIP',
#                    'mediaType': 'application/zip',
#                    'title': 'All resource data'}],
#  'identifier': 'd1e6cc68-12d1-4b8a-8e16-709e80cadd11',
#  'issued': '2017-06-16T22:19:44.810684',
#  'keyword': ['BRFSS',
#              'CHIS',
#              'California Behavorial Risk Factor Surveillance System',
#              'California Breathing',
#              'California Health Interview Survey',
#              'Prevalence',
#              'asthma',
#              'california department of public health',
#              'chronic disease',
#              'disease of respiratory system',
#              'health effects',
#              'health outcome',
#              'respiratory disease'],
#  'license': 'http://www.opendefinition.org/licenses/cc-by',
#  'modified': '2025-11-06T23:04:32.157248',
#  'publisher': {'@type': 'org:Organization',
#                'name': 'California Department of Public Health'},
#  'theme': ['Health and Human Services'],
#  'title': 'Asthma Prevalence'}

# %% [markdown]
# # Request for OpenAQ data

# %% [markdown]
# ## Download and extract geographical data

# %%
import requests
# download county shapefiles from US Census Bureau
shapes_url = 'https://www2.census.gov/geo/tiger/TIGER2025/COUNTY/tl_2025_us_county.zip'
geo_dir = Path("data/geographical")
geo_dir.mkdir(parents=True, exist_ok=True)
shapes_path = geo_dir / "tl_2025_us_county.zip"
if not shapes_path.exists():
    print(f"Downloading county shapefiles from {shapes_url}...")
    r = requests.get(shapes_url)
    with open(shapes_path, 'wb') as f:
        f.write(r.content)
    print(f"Downloaded to {shapes_path}")
else:
    print(f"Shapefiles already exist at {shapes_path}")
# Out:
# Downloading county shapefiles from https://www2.census.gov/geo/tiger/TIGER2025/COUNTY/tl_2025_us_county.zip...
# Downloaded to data/geographical/tl_2025_us_county.zip

# %%
# extract shapefiles to subdirectory
import zipfile
with zipfile.ZipFile(shapes_path, 'r') as zip_ref:
    zip_ref.extractall(geo_dir / "california counties")
print(f"Extracted shapefiles to {geo_dir / 'california counties'}")
# Out:
# Extracted shapefiles to data/geographical/california counties

# %% [markdown]
# ## Inspect geographical data

# %%
# load shapefiles using geopandas
import geopandas as gpd
geo_dir = Path("data/geographical")
shapefile_path = geo_dir / "california counties" / "tl_2025_us_county.shp"
counties_gdf = gpd.read_file(shapefile_path)
counties_gdf.head()
# Out:
#   STATEFP COUNTYFP  COUNTYNS  GEOID         GEOIDFQ      NAME  \
# 0      40      075  01101825  40075  0500000US40075     Kiowa
# 1      46      079  01265776  46079  0500000US46079      Lake
# 2      37      033  01008542  37033  0500000US37033   Caswell
# 3      48      377  01383974  48377  0500000US48377  Presidio
# 4      39      057  01074041  39057  0500000US39057    Greene
#
#           NAMELSAD LSAD CLASSFP  MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT  \
# 0     Kiowa County   06      H1  G4020  None   None     None        A
# 1      Lake County   06      H1  G4020  None   None     None        A
# 2   Caswell County   06      H1  G4020  None   None     None        A
# 3  Presidio County   06      H1  G4020  None   None     None        A
# 4    Greene County   06      H1  G4020   212  19430     None        A
#
#         ALAND    AWATER     INTPTLAT      INTPTLON  \
# 0  2629039892  40296743  +34.9214893  -098.9816168
# 1  1457916151  31746795  +44.0284497  -097.1232229
# 2  1102042927   8293623  +36.3943252  -079.3396193
# 3  9985057447   1773188  +30.0058912  -104.2616192
# 4  1071302625   6798109  +39.6874785  -083.8948943
#
#                                             geometry
# 0  POLYGON ((-98.95506 35.11643, -98.94903 35.116...
# 1  POLYGON ((-96.88886 43.9353, -96.88886 43.9351...
# 2  POLYGON ((-79.14343 36.4422, -79.14345 36.4418...
# 3  POLYGON ((-104.98078 30.62552, -104.98073 30.6...
# 4  POLYGON ((-84.10668 39.68891, -84.10662 39.689...

# %%
# california state uses STATEFP = 06
california_counties = counties_gdf[counties_gdf['STATEFP'] == '06']
california_counties
# Out:
#      STATEFP COUNTYFP  COUNTYNS  GEOID         GEOIDFQ             NAME  \
# 31        06      077  00277303  06077  0500000US06077      San Joaquin
# 74        06      025  00277277  06025  0500000US06025         Imperial
# 272       06      089  01682610  06089  0500000US06089           Shasta
# 357       06      023  01681908  06023  0500000US06023         Humboldt
# 362       06      059  00277294  06059  0500000US06059           Orange
# 383       06      047  00277288  06047  0500000US06047           Merced
# 442       06      105  00277317  06105  0500000US06105          Trinity
# 452       06      053  00277291  06053  0500000US06053         Monterey
# 462       06      005  01675841  06005  0500000US06005           Amador
# 817       06      071  00277300  06071  0500000US06071   San Bernardino
# 963       06      111  00277320  06111  0500000US06111          Ventura
# 1116      06      113  00277321  06113  0500000US06113             Yolo
# 1168      06      041  00277285  06041  0500000US06041            Marin
# 1282      06      001  01675839  06001  0500000US06001          Alameda
# 1344      06      027  01804637  06027  0500000US06027             Inyo
# 1440      06      093  00277311  06093  0500000US06093         Siskiyou
# 1446      06      045  00277287  06045  0500000US06045        Mendocino
# 1458      06      043  00277286  06043  0500000US06043         Mariposa
# 1542      06      017  00277273  06017  0500000US06017        El Dorado
# 1568      06      003  01675840  06003  0500000US06003           Alpine
# 1609      06      021  00277275  06021  0500000US06021            Glenn
# 1695      06      033  00277281  06033  0500000US06033             Lake
# 1714      06      081  00277305  06081  0500000US06081        San Mateo
# 1730      06      029  02054176  06029  0500000US06029             Kern
# 1764      06      069  00277299  06069  0500000US06069       San Benito
# 1779      06      079  00277304  06079  0500000US06079  San Luis Obispo
# 1878      06      039  00277284  06039  0500000US06039           Madera
# 2988  POLYGON ((-122.05188 36.8196, -122.05722 36.83...
# 3046  POLYGON ((-119.17479 36.65888, -119.1747 36.65...
# 3119  POLYGON ((-122.2026 37.36322, -122.20227 37.36...
# 3127  POLYGON ((-122.19917 40.37794, -122.19913 40.3...

# %% [markdown]
# ## Query data from OpenAQ API

# %%
import yaml

with open(Path.cwd() / "code" / "keys.yaml", 'r') as f:
   keys = yaml.safe_load(f)
API_KEY = keys['api_keys']['OpenAQ']
API_KEY
# Out:
# '94e6fcef08ee681b1921a232bc2dcbbaf3959e917a7e4c3e50582c59c9557199'

# %%
# define bounding box for California
x_range = (-125, -113)
y_range = (32, 42.5)

import requests

BASE = "https://api.openaq.org/v3"
headers = {"X-API-Key": API_KEY}

all_results = []
page = 1
limit = 1000   # OpenAQ v3 maximum

while True:
    r = requests.get(
        f"{BASE}/locations",
        headers=headers,
        params={
            "bbox": f"{x_range[0]},{y_range[0]},{x_range[1]},{y_range[1]}",
            "limit": limit,
            "page": page,
            "country": "US",   # optional but helps validation
        },
        timeout=60,
    )
    r.raise_for_status()
    data = r.json()

    results = data.get("results", [])
    if not results:
        break

    all_results.extend(results)
    print(f"page {page}: {len(results)}")

    page += 1

print("TOTAL returned:", len(all_results))
print("first name:", all_results[0].get("name"))
# Out:
# page 1: 1000
# page 2: 980
# TOTAL returned: 1980
# first name: MMFRA1001

# %%
# to dataframe
import pandas as pd
stations_df = pd.json_normalize(all_results)
stations_df.head()
# Out:
#     id             name                          locality  \
# 0  207        MMFRA1001                              None
# 1  211  Felton Cal-Fire                              None
# 2  214        MMFRA1001                              None
# 3  230          Barstow  Riverside-San Bernardino-Ontario
# 4  231   Lucerne Valley                    SAN BERNARDINO
#
#               timezone  isMobile  isMonitor  \
# 0  America/Los_Angeles     False       True
# 1  America/Los_Angeles     False       True
# 2  America/Los_Angeles     False       True
# 3  America/Los_Angeles     False       True
# 4  America/Los_Angeles     False       True
#
#                                  instruments  \
# 0  [{'id': 2, 'name': 'Government Monitor'}]
# 1  [{'id': 2, 'name': 'Government Monitor'}]
# 2  [{'id': 2, 'name': 'Government Monitor'}]
# 3  [{'id': 2, 'name': 'Government Monitor'}]
# 4  [{'id': 2, 'name': 'Government Monitor'}]
#
#                                              sensors  \
# 0  [{'id': 350, 'name': 'pm25 µg/m³', 'parameter'...
# 1  [{'id': 354, 'name': 'pm25 µg/m³', 'parameter'...
# 2  [{'id': 357, 'name': 'pm25 µg/m³', 'parameter'...
# 3  [{'id': 2637, 'name': 'o3 ppm', 'parameter': {...
# 4  [{'id': 7941720, 'name': 'o3 ppm', 'parameter'...
#
#                                             licenses  \
# 0  [{'id': 33, 'name': 'US Public Domain', 'attri...
# 1  [{'id': 33, 'name': 'US Public Domain', 'attri...
# 2  [{'id': 33, 'name': 'US Public Domain', 'attri...
# 3  [{'id': 33, 'name': 'US Public Domain', 'attri...
# 4  [{'id': 33, 'name': 'US Public Domain', 'attri...
#
#                                              bounds  ... provider.id  \
# 0  [-121.221235, 39.482481, -121.221235, 39.482481]  ...         119
# 1      [-122.074603, 37.0481, -122.074603, 37.0481]  ...         119
# 2  [-121.221128, 39.482385, -121.221128, 39.482385]  ...         119
# 3  [-117.024756, 34.894054, -117.024756, 34.894054]  ...         119
# 4      [-116.906874, 34.4101, -116.906874, 34.4101]  ...         119
#
#    provider.name coordinates.latitude coordinates.longitude  \
# 0         AirNow            39.482481           -121.221235
# 1         AirNow            37.048100           -122.074603
# 2         AirNow            39.482385           -121.221128
# 3         AirNow            34.894054           -117.024756
# 4         AirNow            34.410100           -116.906874
#
#       datetimeFirst.utc        datetimeFirst.local      datetimeLast.utc  \
# 0  2016-03-06T20:00:00Z  2016-03-06T12:00:00-08:00  2016-03-16T22:00:00Z
# 1  2016-03-07T15:00:00Z  2016-03-07T07:00:00-08:00  2022-04-08T18:00:00Z
# 2  2016-03-11T17:00:00Z  2016-03-11T09:00:00-08:00  2016-03-16T05:00:00Z
# 3  2016-03-06T20:00:00Z  2016-03-06T12:00:00-08:00  2025-12-21T16:00:00Z
# 4  2016-03-13T10:00:00Z  2016-03-13T03:00:00-07:00  2025-12-21T16:00:00Z
#
#           datetimeLast.local  datetimeFirst  datetimeLast
# 0  2016-03-16T15:00:00-07:00            NaN           NaN
# 1  2022-04-08T11:00:00-07:00            NaN           NaN
# 2  2016-03-15T22:00:00-07:00            NaN           NaN
# 3  2025-12-21T08:00:00-08:00            NaN           NaN
# 4  2025-12-21T08:00:00-08:00            NaN           NaN
#
# [5 rows x 26 columns]

# %%
stations_df.iloc[0]['sensors']
# Out:
# [{'id': 350,
#   'name': 'pm25 µg/m³',
#   'parameter': {'id': 2,
#    'name': 'pm25',
#    'units': 'µg/m³',
#    'displayName': 'PM2.5'}}]

# %%
# save to raw data directory
stations_path = raw_data_dir / "openaq_stations_bbox.xlsx"
stations_df.to_excel(stations_path, index=False, engine='openpyxl')
print(f"Saved OpenAQ stations data to {stations_path}")
# Out:
# Saved OpenAQ stations data to data/raw/openaq_stations_bbox.xlsx

# %% [markdown]
# ## Filter stations in California

# %%
import pandas as pd

stations_df = pd.read_excel(raw_data_dir / "openaq_stations_bbox.xlsx")

# %%
county_geometry = california_counties[['NAME', 'geometry']].set_index('NAME')
# order index
county_geometry = county_geometry.sort_index()
county_geometry
# Out:
#                                                           geometry
# NAME
# Alameda          POLYGON ((-122.37312 37.88388, -122.37114 37.8...
# Alpine           POLYGON ((-120.07333 38.70109, -120.07324 38.7...
# Amador           POLYGON ((-121.02771 38.50011, -121.0277 38.50...
# Butte            POLYGON ((-122.06943 39.84053, -122.06874 39.8...
# Calaveras        POLYGON ((-120.6318 38.34603, -120.63066 38.34...
# Colusa           POLYGON ((-121.91512 38.92535, -121.91527 38.9...
# Contra Costa     POLYGON ((-121.69732 37.78244, -121.69748 37.7...
# Del Norte        POLYGON ((-124.31611 41.72839, -124.33061 41.7...
# El Dorado        POLYGON ((-120.18443 39.03101, -120.1841 39.03...
# Fresno           POLYGON ((-119.57319 36.48884, -119.57322 36.4...
# Glenn            POLYGON ((-122.93818 39.74899, -122.93816 39.7...
# Humboldt         POLYGON ((-124.482 40.44032, -124.47916 40.452...
# Imperial         POLYGON ((-114.72652 32.71827, -114.72706 32.7...
# Inyo             POLYGON ((-118.79003 37.39403, -118.78826 37.3...
# Kern             POLYGON ((-118.88168 34.81785, -118.88204 34.8...
# Kings            POLYGON ((-119.53627 36.06527, -119.53627 36.0...
# Lake             POLYGON ((-122.41588 38.7682, -122.41626 38.76...
# Lassen           POLYGON ((-120.88251 41.18401, -120.88146 41.1...
# Los Angeles      MULTIPOLYGON (((-118.02878 33.87332, -118.0287...
# Madera           POLYGON ((-120.16869 36.80346, -120.16953 36.8...
# Marin            POLYGON ((-122.47283 37.83189, -122.4729 37.83...
# Mariposa         POLYGON ((-120.39534 37.67226, -120.39469 37.6...
# Mendocino        POLYGON ((-123.23896 38.80856, -123.24382 38.8...
# Merced           POLYGON ((-120.5417 37.0445, -120.54179 37.044...
# Modoc            POLYGON ((-120.20886 41.1841, -120.21004 41.18...
# Mono             POLYGON ((-119.65138 38.28664, -119.65018 38.2...
# Monterey         POLYGON ((-122.05188 36.8196, -122.04172 36.82...
# Napa             POLYGON ((-122.10363 38.51216, -122.10364 38.5...
# Nevada           POLYGON ((-120.71714 39.48896, -120.71709 39.4...
# Orange           POLYGON ((-118.09706 33.77438, -118.09706 33.7...
# Placer           POLYGON ((-120.00645 39.28083, -120.00645 39.2...
# Plumas           POLYGON ((-120.77048 39.71776, -120.77082 39.7...
# Riverside        POLYGON ((-114.7665 33.43374, -114.76696 33.43...
# Sacramento       POLYGON ((-121.43991 38.25553, -121.44002 38.2...
# San Benito       POLYGON ((-121.644 36.894, -121.644 36.89401, ...
# San Bernardino   POLYGON ((-114.82952 34.0796, -114.83076 34.07...
# San Diego        POLYGON ((-116.7573 32.56551, -116.78255 32.56...
# San Francisco    MULTIPOLYGON (((-122.40537 37.70829, -122.4055...
# San Joaquin      POLYGON ((-121.17845 37.70553, -121.17886 37.7...
# San Luis Obispo  POLYGON ((-120.71904 35.10983, -120.7223 35.11...
# San Mateo        POLYGON ((-122.58679 37.58998, -122.58645 37.5...
# Santa Barbara    MULTIPOLYGON (((-119.11717 33.5056, -119.11508...
# Santa Clara      POLYGON ((-122.2026 37.36322, -122.20227 37.36...
# Santa Cruz       POLYGON ((-122.05188 36.8196, -122.05722 36.83...
# Shasta           POLYGON ((-121.32288 40.58492, -121.32288 40.5...
# Sierra           POLYGON ((-120.55587 39.50874, -120.55614 39.5...
# Siskiyou         POLYGON ((-122.47877 41.32008, -122.47996 41.3...
# Solano           POLYGON ((-121.8616 38.06989, -121.86229 38.06...
# Sonoma           POLYGON ((-122.63507 38.58301, -122.63506 38.5...
# Stanislaus       POLYGON ((-120.59907 37.55105, -120.60245 37.5...
# Sutter           POLYGON ((-121.61025 39.05691, -121.61026 39.0...
# Tehama           POLYGON ((-122.19917 40.37794, -122.19913 40.3...
# Trinity          POLYGON ((-122.99825 40.41821, -122.99868 40.4...
# Tulare           POLYGON ((-119.17479 36.65888, -119.1747 36.65...
# Tuolumne         POLYGON ((-120.50016 38.00412, -120.50026 38.0...
# Ventura          MULTIPOLYGON (((-119.45458 34.42163, -119.4545...
# Yolo             POLYGON ((-121.66191 38.76292, -121.66213 38.7...
# Yuba             POLYGON ((-121.48786 38.99064, -121.48791 38.9...

# %%
# add county column to stations_df
from shapely.geometry import Point

def get_county(lon, lat, county_gdf):
    point = Point(lon, lat)
    for county_name, row in county_gdf.iterrows():
        if row['geometry'].contains(point):
            return county_name
    return None

stations_df['county'] = stations_df.apply(
    lambda row: get_county(row['coordinates.longitude'], row['coordinates.latitude'], county_geometry),
    axis=1
)
stations_df
# Out:
#            id                        name                          locality  \
# 0         207                   MMFRA1001                               NaN
# 1         211             Felton Cal-Fire                               NaN
# 2         214                   MMFRA1001                               NaN
# 3         230                     Barstow  Riverside-San Bernardino-Ontario
# 4         231              Lucerne Valley                    SAN BERNARDINO
# ...       ...                         ...                               ...
# 1975  6170870              North Alhambra                               NaN
# 1976  6172339  Carson City - Indian Hills                               NaN
# 1977  6172496                 SJVAir-af04                               NaN
# 1978  6172684        Center St, Stratford                               NaN
# 1979  6172685         Cross St, Stratford                               NaN
#
#                  timezone  isMobile  isMonitor  \
# 0     America/Los_Angeles     False       True
# 1     America/Los_Angeles     False       True
# 2     America/Los_Angeles     False       True
# 3     America/Los_Angeles     False       True
# 4     America/Los_Angeles     False       True
# ...                   ...       ...        ...
# 1975  America/Los_Angeles     False      False
# 1976  America/Los_Angeles     False      False
# 1977  America/Los_Angeles     False      False
# 1978  America/Los_Angeles     False      False
# 1979  America/Los_Angeles     False      False
#
#                                             instruments  \
# 0             [{'id': 2, 'name': 'Government Monitor'}]
# 1             [{'id': 2, 'name': 'Government Monitor'}]
# 2             [{'id': 2, 'name': 'Government Monitor'}]
# 3             [{'id': 2, 'name': 'Government Monitor'}]
# 4             [{'id': 2, 'name': 'Government Monitor'}]
# ...                                                 ...
# 1975  [{'id': 7, 'name': 'Unknown AirGradient Sensor'}]
# 1976  [{'id': 7, 'name': 'Unknown AirGradient Sensor'}]
# 1977  [{'id': 7, 'name': 'Unknown AirGradient Sensor'}]
# 1978  [{'id': 7, 'name': 'Unknown AirGradient Sensor'}]
# 1979  [{'id': 7, 'name': 'Unknown AirGradient Sensor'}]
#
#                                                 sensors  \
# 0     [{'id': 350, 'name': 'pm25 µg/m³', 'parameter'...
# 1     [{'id': 354, 'name': 'pm25 µg/m³', 'parameter'...
# 2     [{'id': 357, 'name': 'pm25 µg/m³', 'parameter'...
# 3     [{'id': 2637, 'name': 'o3 ppm', 'parameter': {...
# 4     [{'id': 7941720, 'name': 'o3 ppm', 'parameter'...
# ...                                                 ...
# 1975  [{'id': 14935594, 'name': 'pm1 µg/m³', 'parame...
# 1976  [{'id': 14946536, 'name': 'pm1 µg/m³', 'parame...
# 1977  [{'id': 14947719, 'name': 'pm1 µg/m³', 'parame...
# 1978  [{'id': 14949136, 'name': 'pm1 µg/m³', 'parame...
# 1979  [{'id': 14949141, 'name': 'pm1 µg/m³', 'parame...
#
#                                                licenses  \
# 0     [{'id': 33, 'name': 'US Public Domain', 'attri...
# 1     [{'id': 33, 'name': 'US Public Domain', 'attri...
# 2     [{'id': 33, 'name': 'US Public Domain', 'attri...
# 3     [{'id': 33, 'name': 'US Public Domain', 'attri...
# 4     [{'id': 33, 'name': 'US Public Domain', 'attri...
# ...                                                 ...
# 1975  [{'id': 41, 'name': 'CC BY 4.0', 'attribution'...
# 1976  [{'id': 41, 'name': 'CC BY 4.0', 'attribution'...
# 1977  [{'id': 41, 'name': 'CC BY 4.0', 'attribution'...
# 1978  [{'id': 41, 'name': 'CC BY 4.0', 'attribution'...
# 1979  [{'id': 41, 'name': 'CC BY 4.0', 'attribution'...
# 1979  2025-12-21T08:00:00-08:00           NaN           NaN           Kings
#
# [1980 rows x 27 columns]

# %%
california_stations_df = stations_df[stations_df['county'].notnull()]
california_stations_df
# Out:
#            id                  name                          locality  \
# 0         207             MMFRA1001                               NaN
# 1         211       Felton Cal-Fire                               NaN
# 2         214             MMFRA1001                               NaN
# 3         230               Barstow  Riverside-San Bernardino-Ontario
# 4         231        Lucerne Valley                    SAN BERNARDINO
# ...       ...                   ...                               ...
# 1974  6169863     1417 Cabrillo Ave                               NaN
# 1975  6170870        North Alhambra                               NaN
# 1977  6172496           SJVAir-af04                               NaN
# 1978  6172684  Center St, Stratford                               NaN
# 1979  6172685   Cross St, Stratford                               NaN
#
#                  timezone  isMobile  isMonitor  \
# 0     America/Los_Angeles     False       True
# 1     America/Los_Angeles     False       True
# 2     America/Los_Angeles     False       True
# 3     America/Los_Angeles     False       True
# 4     America/Los_Angeles     False       True
# ...                   ...       ...        ...
# 1974  America/Los_Angeles     False      False
# 1975  America/Los_Angeles     False      False
# 1977  America/Los_Angeles     False      False
# 1978  America/Los_Angeles     False      False
# 1979  America/Los_Angeles     False      False
#
#                                             instruments  \
# 0             [{'id': 2, 'name': 'Government Monitor'}]
# 1             [{'id': 2, 'name': 'Government Monitor'}]
# 2             [{'id': 2, 'name': 'Government Monitor'}]
# 3             [{'id': 2, 'name': 'Government Monitor'}]
# 4             [{'id': 2, 'name': 'Government Monitor'}]
# ...                                                 ...
# 1974  [{'id': 7, 'name': 'Unknown AirGradient Sensor'}]
# 1975  [{'id': 7, 'name': 'Unknown AirGradient Sensor'}]
# 1977  [{'id': 7, 'name': 'Unknown AirGradient Sensor'}]
# 1978  [{'id': 7, 'name': 'Unknown AirGradient Sensor'}]
# 1979  [{'id': 7, 'name': 'Unknown AirGradient Sensor'}]
#
#                                                 sensors  \
# 0     [{'id': 350, 'name': 'pm25 µg/m³', 'parameter'...
# 1     [{'id': 354, 'name': 'pm25 µg/m³', 'parameter'...
# 2     [{'id': 357, 'name': 'pm25 µg/m³', 'parameter'...
# 3     [{'id': 2637, 'name': 'o3 ppm', 'parameter': {...
# 4     [{'id': 7941720, 'name': 'o3 ppm', 'parameter'...
# ...                                                 ...
# 1974  [{'id': 14928467, 'name': 'pm1 µg/m³', 'parame...
# 1975  [{'id': 14935594, 'name': 'pm1 µg/m³', 'parame...
# 1977  [{'id': 14947719, 'name': 'pm1 µg/m³', 'parame...
# 1978  [{'id': 14949136, 'name': 'pm1 µg/m³', 'parame...
# 1979  [{'id': 14949141, 'name': 'pm1 µg/m³', 'parame...
#
#                                                licenses  \
# 0     [{'id': 33, 'name': 'US Public Domain', 'attri...
# 1     [{'id': 33, 'name': 'US Public Domain', 'attri...
# 2     [{'id': 33, 'name': 'US Public Domain', 'attri...
# 3     [{'id': 33, 'name': 'US Public Domain', 'attri...
# 4     [{'id': 33, 'name': 'US Public Domain', 'attri...
# ...                                                 ...
# 1974  [{'id': 41, 'name': 'CC BY 4.0', 'attribution'...
# 1975  [{'id': 41, 'name': 'CC BY 4.0', 'attribution'...
# 1977  [{'id': 41, 'name': 'CC BY 4.0', 'attribution'...
# 1978  [{'id': 41, 'name': 'CC BY 4.0', 'attribution'...
# 1979  [{'id': 41, 'name': 'CC BY 4.0', 'attribution'...
#
#                                                  bounds  ...  provider.name  \
# 0      [-121.221235, 39.482481, -121.221235, 39.482481]  ...         AirNow
# 1          [-122.074603, 37.0481, -122.074603, 37.0481]  ...         AirNow
# 2      [-121.221128, 39.482385, -121.221128, 39.482385]  ...         AirNow
# 3      [-117.024756, 34.894054, -117.024756, 34.894054]  ...         AirNow
# 4          [-116.906874, 34.4101, -116.906874, 34.4101]  ...         AirNow
# ...                                                 ...  ...            ...
# 1974       [-122.37466, 37.58592, -122.37466, 37.58592]  ...    AirGradient
# 1975  [-118.13855657348095, 34.09975528725245, -118....  ...    AirGradient
# Santa Clara         34
# San Mateo           34
# Humboldt            33
# Santa Cruz          32
# El Dorado           28
# Ventura             26
# Shasta              25
# Fresno              23
# Yuba                22
# Napa                19
# Mendocino           19
# Siskiyou            18
# Marin               15
# Butte               13
# Merced              12
# Alpine              12
# Imperial            11
# Kings               11
# Lake                10
# Placer              10
# Mariposa            10
# San Joaquin          9
# Sutter               9
# Yolo                 8
# San Benito           8
# Nevada               6
# Plumas               6
# Madera               6
# Del Norte            6
# Solano               6
# Stanislaus           4
# Colusa               3
# Tehama               3
# Lassen               3
# Amador               2
# Glenn                2
# Calaveras            1
# Trinity              1
# Tuolumne             1
# dtype: int64

# %%
openaq_dir = Path("data/openaq_data")
california_stations_df.to_excel(openaq_dir / "california_stations.xlsx", index=False, engine='openpyxl')
print(f"Saved California OpenAQ stations data to {openaq_dir / 'california_stations.xlsx'}")
# Out:
# Saved California OpenAQ stations data to data/openaq_data/california_stations.xlsx

# %% [markdown]
# ## Request data for each station

# %%
# We choose one station per county
import pandas as pd
openaq_dir = Path("data/openaq_data")
california_stations_df = pd.read_excel(openaq_dir / "california_stations.xlsx")
selected_stations = california_stations_df.copy()
selected_stations
# Out:
#            id                  name                          locality  \
# 0         207             MMFRA1001                               NaN
# 1         211       Felton Cal-Fire                               NaN
# 2         214             MMFRA1001                               NaN
# 3         230               Barstow  Riverside-San Bernardino-Ontario
# 4         231        Lucerne Valley                    SAN BERNARDINO
# ...       ...                   ...                               ...
# 1873  6169863     1417 Cabrillo Ave                               NaN
# 1874  6170870        North Alhambra                               NaN
# 1875  6172496           SJVAir-af04                               NaN
# 1876  6172684  Center St, Stratford                               NaN
# 1877  6172685   Cross St, Stratford                               NaN
#
#                  timezone  isMobile  isMonitor  \
# 0     America/Los_Angeles     False       True
# 1     America/Los_Angeles     False       True
# 2     America/Los_Angeles     False       True
# 3     America/Los_Angeles     False       True
# 4     America/Los_Angeles     False       True
# ...                   ...       ...        ...
# 1873  America/Los_Angeles     False      False
# 1874  America/Los_Angeles     False      False
# 1875  America/Los_Angeles     False      False
# 1876  America/Los_Angeles     False      False
# 1877  America/Los_Angeles     False      False
#
#                                             instruments  \
# 0             [{'id': 2, 'name': 'Government Monitor'}]
# 1             [{'id': 2, 'name': 'Government Monitor'}]
# 2             [{'id': 2, 'name': 'Government Monitor'}]
# 3             [{'id': 2, 'name': 'Government Monitor'}]
# 4             [{'id': 2, 'name': 'Government Monitor'}]
# ...                                                 ...
# 1873  [{'id': 7, 'name': 'Unknown AirGradient Sensor'}]
# 1874  [{'id': 7, 'name': 'Unknown AirGradient Sensor'}]
# 1875  [{'id': 7, 'name': 'Unknown AirGradient Sensor'}]
# 1876  [{'id': 7, 'name': 'Unknown AirGradient Sensor'}]
# 1877  [{'id': 7, 'name': 'Unknown AirGradient Sensor'}]
#
#                                                 sensors  \
# 0     [{'id': 350, 'name': 'pm25 µg/m³', 'parameter'...
# 1     [{'id': 354, 'name': 'pm25 µg/m³', 'parameter'...
# 2     [{'id': 357, 'name': 'pm25 µg/m³', 'parameter'...
# 3     [{'id': 2637, 'name': 'o3 ppm', 'parameter': {...
# 4     [{'id': 7941720, 'name': 'o3 ppm', 'parameter'...
# ...                                                 ...
# 1873  [{'id': 14928467, 'name': 'pm1 µg/m³', 'parame...
# 1874  [{'id': 14935594, 'name': 'pm1 µg/m³', 'parame...
# 1875  [{'id': 14947719, 'name': 'pm1 µg/m³', 'parame...
# 1876  [{'id': 14949136, 'name': 'pm1 µg/m³', 'parame...
# 1877  [{'id': 14949141, 'name': 'pm1 µg/m³', 'parame...
#
#                                                licenses  \
# 0     [{'id': 33, 'name': 'US Public Domain', 'attri...
#
# 0     2016-03-16T15:00:00-07:00           NaN           NaN            Yuba
# 1     2022-04-08T11:00:00-07:00           NaN           NaN      Santa Cruz
# 2     2016-03-15T22:00:00-07:00           NaN           NaN            Yuba
# 3     2025-12-21T08:00:00-08:00           NaN           NaN  San Bernardino
# 4     2025-12-21T08:00:00-08:00           NaN           NaN  San Bernardino
# ...                         ...           ...           ...             ...
# 1873  2025-12-21T08:00:00-08:00           NaN           NaN       San Mateo
# 1874  2025-12-21T08:00:00-08:00           NaN           NaN     Los Angeles
# 1875  2025-12-21T08:00:00-08:00           NaN           NaN          Fresno
# 1876  2025-12-21T08:00:00-08:00           NaN           NaN           Kings
# 1877  2025-12-21T08:00:00-08:00           NaN           NaN           Kings
#
# [1878 rows x 27 columns]

# %%
# estimate number of sensors, first convert text to json
import json
selected_stations['sensors_count'] = selected_stations['sensors'].apply(lambda x: len(json.loads(x.replace("'", '"'))))
selected_stations['sensors_count'].sum()
# Out:
# np.int64(5333)

# %%
# The API has a rate limit of 60 per minute and 2000 per hour.
from tqdm import tqdm
import time, requests

SENSOR_BASE = "https://api.openaq.org/v3/sensors"
aq_data_path = Path("data/openaq_data")
aq_data_path.mkdir(parents=True, exist_ok=True)
pbar = tqdm(total=selected_stations['sensors_count'].sum())
headers = {"X-API-Key": API_KEY}
for _, row in selected_stations.iterrows():
    station = row
    sensors_list = json.loads(row['sensors'].replace("'", '"'))
    for sensor in sensors_list:
        # check if sensor data file already exists
        sensor_filename = aq_data_path / "sensors" / f"sensor_{sensor['id']}.json"
        if sensor_filename.exists():
            pbar.update(1)
            continue
        sensor_id = sensor['id']
        r = requests.get(
            f"{SENSOR_BASE}/{sensor_id}/measurements",
            headers=headers,
            timeout=60,
            params={
                "date_from": "2015-01-01T00:00:00+00:00",
                "date_to": "2024-12-31T23:59:59+00:00",
            }
        )
        if r.headers.get('X-RateLimit-Remaining') == '0':
            reset_time = int(r.headers.get('X-RateLimit-Reset', 60))
            pbar.set_description(f"Rate limit reached. Sleeping for {reset_time + 1} seconds...")
            time.sleep(reset_time + 1)
            r = requests.get(
                f"{SENSOR_BASE}/{sensor_id}/measurements",
                headers=headers,
                timeout=60,
                params={
                    "date_from": "2015-01-01T00:00:00+00:00",
                    "date_to": "2024-12-31T23:59:59+00:00",
                }
            )
        sensor_data = r.json().get("results", {})
        # save sensor data to file
        sensor_file_path = aq_data_path / "sensors" / f"sensor_{sensor_id}.json"
        with open(sensor_file_path, 'w') as f:
            json.dump(sensor_data, f, indent=4)
        pbar.set_description(f"Saved sensor data to {sensor_file_path}")
        # append to metadata dataframe
        pbar.update(1)
        if r.headers.get('X-RateLimit-Remaining') == '0':
            reset_time = int(r.headers.get('X-RateLimit-Reset', 60))
            pbar.set_description(f"Rate limit reached. Sleeping for {reset_time + 1} seconds...")
            time.sleep(reset_time + 1)wthtn
pbar.close()
# Out:
# Saved sensor data to data/openaq_data/sensors/sensor_14949145.json: 100%|███████████| 5333/5333 [43:04<00:00,  2.06it/s]

# %%
sensor_metadata_df = pd.DataFrame(columns=[
    'county', 'station_id', 'sensor_id', 'pollutant', 'unit'
])
for _, row in selected_stations.iterrows():
    station = row
    sensors_list = row['sensors']
    for sensor in sensors_list:
        sensor_metadata_df.loc[len(sensor_metadata_df)] = {
            'county': station['county'],
            'station_id': station['id'],
            'sensor_id': sensor['id'],
            'pollutant': sensor['parameter']['name'],
            'unit': sensor['parameter']['units'],
        }
sensor_metadata_df.to_csv(aq_data_path / "sensor_metadata.csv", index=False)

# %% [markdown]
# # Build SQL Database for OpenAQ Data

# %%
print(Path.cwd())
# Out:
# /mnt/c/Users/Usuario/PycharmProjects/data-life-cycle-project-2025

# %%
sql_script_path = Path("code") / "aq_schema.sql"
db_path = Path("data") / "openaq_data" / "unified.db"
import sqlite3

conn = sqlite3.connect(db_path)
c = conn.cursor()

with open(sql_script_path, 'r') as f:
    sql_script = f.read()

c.executescript(sql_script)
conn.commit()
conn.close()

# %% [markdown]
# ## Insert sensor metadata into database

# %%
import sqlite3
import pandas as pd
from tqdm.notebook import tqdm
from pathlib import Path
import geopandas as gpd

aq_data_path = Path("data/openaq_data")
sensor_metadata_path = aq_data_path / "sensor_metadata.csv"
sensor_metadata_df = pd.read_csv(sensor_metadata_path)

geo_dir = Path("data/geographical")
california_counties = gpd.read_file(
    geo_dir / "california counties" / "tl_2025_us_county.shp"
)
california_counties = california_counties[california_counties['STATEFP'] == '06']

selected_stations = stations_df[stations_df['county'].notnull()]

conn = sqlite3.connect(db_path)
c = conn.cursor()
pbar = tqdm(total=len(sensor_metadata_df))
for _, sensor in sensor_metadata_df.iterrows():
   county_name = sensor['county']
   county_id = pd.read_sql(
      "SELECT county_id FROM counties WHERE county_name = ?",
      conn,
      params=(county_name,)
   )
   # insert county if not exists, else get county_id
   if len(county_id) == 0:
      # get last index
      county_id = 1 + len(pd.read_sql("SELECT * FROM counties", conn))
      county_geometry = california_counties[
          california_counties['NAME'] == county_name
          ]['geometry'].values[0]
      c.execute(
         "INSERT INTO counties (county_id, county_name, geometry) VALUES (?, ?, ?)",
      (county_id, county_name, str(county_geometry))
      )
   else:
      county_id = county_id['county_id'].values[0]
   county_id = int(county_id)
   # insert station if not exists, else get station_id
   station_id = pd.read_sql(
      "SELECT station_id FROM stations WHERE station_id = ?",
      conn,
      params=(sensor['station_id'],)
   )
   if len(station_id) == 0:
      station_id = 1 + len(pd.read_sql("SELECT * FROM stations", conn))
      c.execute(
         "INSERT INTO stations (station_id, county_id, latitude, longitude) VALUES (?, ?, ?, ?)",
         (
            sensor['station_id'],
            county_id,
            selected_stations[
               selected_stations['id'] == sensor['station_id']
            ]['coordinates.latitude'].values[0],
            selected_stations[
               selected_stations['id'] == sensor['station_id']
            ]['coordinates.longitude'].values[0],
         )
      )
   else:
      station_id = station_id['station_id'].values[0]
   station_id = int(station_id)
   # insert unit if not exists, else get unit_id
   unit_id = pd.read_sql(
      "SELECT unit_id FROM units WHERE unit_name = ?", conn, params=(sensor['pollutant'],)
   )
   if len(unit_id) == 0:
      unit_id = 1 + len(pd.read_sql("SELECT * FROM units", conn))
      c.execute(
         "INSERT INTO units (unit_id, unit_name) VALUES (?, ?)",
         (unit_id, sensor['unit'])
      )
   else:
      unit_id = unit_id['unit_id'].values[0]
   unit_id = int(unit_id)
   # insert pollutant if not exists, else get pollutant_id
   pollutant_id = pd.read_sql("SELECT pollutant_id FROM pollutants WHERE pollutant_name = ?", conn, params=(sensor['pollutant'],))
   if len(pollutant_id) == 0:
      pollutant_id = 1 + len(pd.read_sql("SELECT * FROM pollutants", conn))
      c.execute(
         "INSERT INTO pollutants (pollutant_id, pollutant_name) VALUES (?, ?)",
         (pollutant_id, sensor['pollutant'])
      )
   else:
      pollutant_id = pollutant_id['pollutant_id'].values[0]
   pollutant_id = int(pollutant_id)
   # insert sensor
   sensor_id = pd.read_sql("SELECT sensor_id FROM sensors WHERE sensor_id = ?", conn, params=(sensor['sensor_id'],))
   if len(sensor_id) == 0:
      sensor_id = 1 + len(pd.read_sql("SELECT * FROM sensors", conn))
      c.execute(
         "INSERT INTO sensors (sensor_id, station_id, pollutant_id, unit_id) VALUES (?, ?, ?, ?)",
         (sensor['sensor_id'], station_id, pollutant_id, unit_id)
      )
   pbar.update(1)
pbar.close()
conn.commit()
conn.close()
# Out:
#   0%|          | 0/5333 [00:00<?, ?it/s]

# %% [markdown]
# ## Insert measurements into database

# %%
from pathlib import Path
aq_data_path = Path("data/openaq_data")
sensor_files = list((aq_data_path / "sensors").glob("sensor_*.json"))
sensor_files
# Out:
# [PosixPath('data/openaq_data/sensors/sensor_10031777.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10097888.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10135880.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10141007.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10141027.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10141028.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10141034.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10141041.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10141043.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10141045.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10141054.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10141061.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10141083.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10141087.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10141090.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10141094.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10161292.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10161301.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10161306.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10161313.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10161316.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10161322.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10164835.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10164837.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10164839.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10164841.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10164842.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10164846.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10166120.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10166124.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10166129.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10166130.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10166132.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10166151.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10185539.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10185540.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10206345.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10206347.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10206363.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10206364.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10206370.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10206372.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10228004.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10228005.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10228006.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10228012.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10228019.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10228020.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10231424.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10280871.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10280881.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10280886.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10280894.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10280907.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10280909.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10281844.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10281859.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10281898.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10281899.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10281902.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10281904.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10293059.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10294265.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10294269.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10294273.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10294276.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10294277.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10294279.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10295507.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10295508.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10295529.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10295533.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10295537.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10295541.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10296421.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10296436.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10296439.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10296448.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10296450.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10296452.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10401939.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10401950.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10401951.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10401961.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10401986.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10401995.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10405895.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10405897.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10405898.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10405903.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10405908.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10405912.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10410521.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10410537.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10410538.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10410539.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10410565.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10410566.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10411449.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10411456.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10411468.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10411478.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10411512.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10411513.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10412214.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10424079.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10424082.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10424105.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10424110.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10424114.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10424116.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10431019.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10431039.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10431045.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10431047.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10431064.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10431082.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10434970.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10434971.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10445563.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10445569.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10445571.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10445573.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10445576.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10445587.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10445592.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10455056.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10455060.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10455072.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10455074.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10455079.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10455085.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10489416.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10489421.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10489422.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10489426.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10489428.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10489430.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10556441.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10556443.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10556444.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10556446.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10556449.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10556452.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10577000.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10577008.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10580244.json'),
#  PosixPath('data/openaq_data/sensors/sensor_10580245.json'),
#  PosixPath('data/openaq_data/sensors/sensor_
json'),
#  PosixPath('data/openaq_data/sensors/sensor_12866271.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12866272.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12866273.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12866274.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12866275.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12866276.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12866278.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12866279.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12866280.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12866281.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12866282.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12866283.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12866284.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12866285.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12866286.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12866287.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12866288.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12874060.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12874061.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12874062.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12874063.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12874064.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12883902.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12927271.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12940.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12967046.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12967047.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12967048.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12967049.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12967050.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12967051.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1297330.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1297486.json'),
#  PosixPath('data/openaq_data/sensors/sensor_12983.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13000639.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13014564.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13014565.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13014566.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13014567.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13014568.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1301534.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1301775.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1301892.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13036197.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13036198.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13036199.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13036200.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13036201.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13051826.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13053696.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1306119.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1306120.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13069.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1309441.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1309442.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13096.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1311945.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13150.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13159056.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13159057.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13159058.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13159059.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13159060.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1316140.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1316149.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1316155.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1316221.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1316222.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1316346.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1316418.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13177881.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13177882.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13177883.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13177884.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13177885.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13177886.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13177887.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13177888.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13177889.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13177890.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13178754.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13179.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13179311.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1319692.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1319693.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1322019.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1322922.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1324228.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13271667.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13288294.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1328938.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1328958.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13296352.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13296644.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13296645.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13299516.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13299517.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13299518.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13299519.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13299520.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1330050.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1330670.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13312955.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13324600.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13324601.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13324602.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13324603.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13324604.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1334168.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13362472.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13362473.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13362474.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13362475.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13362476.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1337240.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13376.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13377.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13423164.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13423165.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13423166.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13423167.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13423168.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13437912.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13437913.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13437914.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13437915.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13437916.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13469113.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13469114.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13469115.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13469116.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13469117.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1347700.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13486014.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13486015.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13486016.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13486017.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13486018.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1349599.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1349630.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1349632.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1349823.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1349963.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13501565.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13501566.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13501567.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13501568.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13501569.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13531.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13535.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13540.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13543.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13546606.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13546607.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13546608.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13546609.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13546610.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13549.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13550.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13552.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13557630.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13558.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13559715.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13559716.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13559717.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13559718.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13559719.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13564438.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13564968.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13564969.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13564970.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13574377.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13575454.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13576.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13584268.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13584269.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13584270.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13584271.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13584272.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13606.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1361.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1362.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1363.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1364.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1365.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1366.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13663636.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13663637.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13663638.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13663639.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13663640.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1367.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13675959.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13676221.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13676222.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13676223.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1368.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1369.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1370.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13704199.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13704200.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13704201.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13704202.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13704203.json'),
#  PosixPath('data/openaq_data/sensors/sensor_1371.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13719081.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13738335.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13747080.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13772485.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13779498.json'),
#  PosixPath('data/openaq_data/sensors/sensor_13779499.json'),
#  ...]

# %%
import re, sqlite3
from tqdm import tqdm
import pandas as pd

pbar = tqdm(total=len(sensor_files))
db_path = Path("data") / "openaq_data" / "unified.db"
conn = sqlite3.connect(db_path)
c = conn.cursor()
for sensor_file in sensor_files:
    sensor_df = pd.read_json(sensor_file)
    sensor_id = int(re.search(r'sensor_(\d+)\.json', sensor_file.name).group(1))
    # insert measurements into database
    for _, measurement in sensor_df.iterrows():
        value = measurement['value']
        start_time = measurement['period']['datetimeFrom']['utc']
        end_time = measurement['period']['datetimeTo']['utc']
        try:
           c.execute(
               "INSERT INTO measurements (sensor_id, measurement_value, start_time, end_time) VALUES (?, ?, ?, ?)",
               (sensor_id, value, start_time, end_time)
           )
        except sqlite3.IntegrityError:
             # skip duplicate entries
             continue
    conn.commit()
    pbar.update(1)
pbar.close()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 5333/5333 [00:54<00:00, 98.32it/s]
